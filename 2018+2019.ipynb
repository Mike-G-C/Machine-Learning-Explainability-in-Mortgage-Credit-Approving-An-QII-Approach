# %%
import matplotlib.pyplot as plt
import pandas as pd
pd.options.display.max_rows = 70
df1 = pd.read_csv("2018_lar_10.csv", delimiter = ",")
df2 = pd.read_csv("2019_lar_sample.csv", delimiter = ",")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513977 entries, 0 to 1513976
# Data columns (total 99 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   activity_year                     1513977 non-null  int64
#  1   lei                               1513783 non-null  object
#  2   derived_msa_md                    1513977 non-null  int64
#  3   state_code                        1493450 non-null  object
#  4   county_code                       1477700 non-null  object
#  5   census_tract                      1474074 non-null  object
#  6   conforming_loan_limit             1507356 non-null  object
#  7   derived_loan_product_type         1513783 non-null  object
#  8   derived_dwelling_category         1513783 non-null  object
#  9   derived_ethnicity                 1513977 non-null  object
#  10  derived_race                      1513977 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175591 entries, 0 to 175590
# Data columns (total 99 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   activity_year                     175591 non-null  int64
#  1   lei                               175590 non-null  object
#  2   derived_msa_md                    175591 non-null  int64
#  3   state_code                        173712 non-null  object
#  4   county_code                       172174 non-null  float64
#  5   census_tract                      171793 non-null  float64
#  6   conforming_loan_limit             174904 non-null  object
#  7   derived_loan_product_type         175590 non-null  object
#  8   derived_dwelling_category         175590 non-null  object
#  9   derived_ethnicity                 175591 non-null  object
#  10  derived_race                      175591 non-null  object
# ...

# %%
df3 = pd.concat([df1, df2], ignore_index = True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1689568 entries, 0 to 1689567
# Data columns (total 99 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   activity_year                     1689568 non-null  int64
#  1   lei                               1689373 non-null  object
#  2   derived_msa_md                    1689568 non-null  int64
#  3   state_code                        1667162 non-null  object
#  4   county_code                       1649874 non-null  object
#  5   census_tract                      1645867 non-null  object
#  6   conforming_loan_limit             1682260 non-null  object
#  7   derived_loan_product_type         1689373 non-null  object
#  8   derived_dwelling_category         1689373 non-null  object
#  9   derived_ethnicity                 1689568 non-null  object
#  10  derived_race                      1689568 non-null  object
# ...

# %%
df3.to_csv("lar_10.csv")
